# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("H:/group_project2/machine_learning/CWPT2/trainDataset.csv")
df.head()
# Out:
#           ID  pCR (outcome)  RelapseFreeSurvival (outcome)   Age  ER  PgR  \
# 0  TRG002174              1                          144.0  41.0   0    0
# 1  TRG002178              0                          142.0  39.0   1    1
# 2  TRG002204              1                          135.0  31.0   0    0
# 3  TRG002206              0                           12.0  35.0   0    0
# 4  TRG002210              0                          109.0  61.0   1    0
#
#    HER2  TrippleNegative  ChemoGrade  Proliferation  ...  \
# 0     0                1           3              3  ...
# 1     0                0           3              3  ...
# 2     0                1           2              1  ...
# 3     0                1           3              3  ...
# 4     0                0           2              1  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       0.517172
# 1                                       0.444391
# ...

# %%
df_numerical = df.drop(columns = ['ID', 'RelapseFreeSurvival (outcome)', 'ER', 'PgR', 'HER2', 'TrippleNegative', 'ChemoGrade',
                                'Proliferation', 'HistologyType', 'LNStatus', 'TumourStage'])

fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(10,20))
fig.subplots_adjust(hspace =0.75, wspace=0.2)
axes = axes.ravel()

for i, col in enumerate(df_numerical.columns[1:19]):
    _= sns.boxplot(y=col, x='pCR (outcome)', data=df_numerical, ax=axes[i])
